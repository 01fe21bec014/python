# %% [markdown]
# Adding the Tuples

# %%
tuple1=("123","abc","#@!")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
# Out:
# 123
# abc
# #@!

# %%
tuple2=(":?|","1002","&*^%")
print(tuple2[0])
print(tuple2[1])
print(tuple2[2])
# Out:
# :?|
# 1002
# &*^%

# %%
tuple3=tuple1+tuple2
print(tuple3)
# Out:
# (':?|', '1002', '&*^%', ':?|', '1002', '&*^%')

# %% [markdown]
# Sorting the list

# %%
list=['sunil','123','17.10','xyz','abc']
type(list)
# Out:
# list

# %%
print(list)
# Out:
# ['sunil', '123', '17.10', 'xyz', 'abc']

# %%
list1=['abd','900','17.111110','mankind','pocket']
type(list1)
# Out:
# list

# %%
print(list1)
# Out:
# ['abd', '900', '17.111110', 'mankind', 'pocket']

# %%
list2=list+list1
print(list2)
# Out:
# ['123', '17.10', 'abc', 'sunil', 'xyz', 'abd', '900', '17.111110', 'mankind', 'pocket']

# %%
list.sort()

# %%
list
# Out:
# ['123', '17.10', 'abc', 'sunil', 'xyz']

# %%
list1.sort()

# %%
list1
# Out:
# ['17.111110', '900', 'abd', 'mankind', 'pocket']

# %%
list2.sort()

# %%
list2
# Out:
# ['123',
#  '17.10',
#  '17.111110',
#  '900',
#  'abc',
#  'abd',
#  'mankind',
#  'pocket',
#  'sunil',
#  'xyz']

# %% [markdown]
# Airthmetic operation

# %%
x=50
y=15
sum=x+y
diff=x-y
prod=x*y
div=x/y
fdiv=x//y
mod=x%y
power=x**y
print(sum)
print(diff)
print(prod)
print(div)
print(fdiv)
print(mod)
print(power)
# Out:
# 65
# 35
# 750
# 3.3333333333333335
# 3
# 5
# 30517578125000000000000000

# %% [markdown]
# Condition statements

# %%
a=input("enter the value of a")
b=input("enter the value of b")
c=input("enter the value of c")
d=input("enter the value of d")
e=input("enter the value of e")
f=input("enter the value of f")
print(a)
print(b)
print(a)
print(b)
print(e)
print(f)
# Out:
# enter the value of a1
# enter the value of b2
# enter the value of c4
# enter the value of d6
# enter the value of e7
# enter the value of f8
# 1
# 2
# 1
# 2
# 7
# 8

# %%
if a>b:
  print(" a is greater than b")
#if a==b:
  #print("a and b are same")
else:
  print('a is lesser than b')
# Out:
# a is lesser than b

# %%
if e<f:
  print(" e is lesser than f")
#if e==f:
  #print("e and f are same")
else:
  print('e is greater than f')
# Out:
#  e is lesser than f

# %% [markdown]
# Adding the Tuples and counting the reapeated values

# %%
tuple1=("123","abc","#@!")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
# Out:
# 123
# abc
# #@!

# %%
tuple2=(":?|","1002","&*^%")
print(tuple2[0])
print(tuple2[1])
print(tuple2[2])
# Out:
# :?|
# 1002
# &*^%

# %%
tuple3=tuple2+tuple1
print(tuple3)
tuple4=tuple3*2
print(tuple4)
# Out:
# (':?|', '1002', '&*^%', '123', 'abc', '#@!')
# (':?|', '1002', '&*^%', '123', 'abc', '#@!', ':?|', '1002', '&*^%', '123', 'abc', '#@!')

# %%
y=tuple4.index('1002')
print(y)

x=tuple4.count('123')
print(x)
# Out:
# 1
# 2
