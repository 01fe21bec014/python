# %% [markdown]
# **My first program**

# %%
print("I am Sunil")
# Out:
# I am Sunil

# %%
a+b

# %% [markdown]
# **Variable Declariation in Python**
# Rule1:Variable should always start with alphabit or number
# Rule2:Variable should not  start with some  number or special character Ex:1stnum=5
# Rule3:Variable Declariation is case sensitive
# Name name NamE
# Name=90
# NamE=70

# %%
a=5
b=9
sum=a+b
print(sum)
print("sum")
# Out:
# 14
# sum

# %%
a=6
b=9
c=9
d=6
s=a-b
t=c-d
sum=s-t
print(sum)
print("sum")
# Out:
# -6
# sum

# %%
a=6
b=9
c=9
d=6
s=a*b
t=c*d
sum=s*t
print(sum)
print("sum")
# Out:
# 2916
# sum

# %%
a=2
b=2
c=3
d=3
s=a**b
t=c**d
sum=s**t
print("s=")
print(s)
print("t=")
print(t)
print("sum=")
print(sum)
# Out:
# s=
# 4
# t=
# 27
# sum=
# 18014398509481984

# %%
a=15
b=5
sum=a/b
rem=a%b
print(sum)
print(rem)
# Out:
# 3.0
# 0

# %%
from math import sqrt
square_root=sqrt(25)
print(square_root)
# Out:
# 5.0

# %% [markdown]
# Day 4 proceeding
# **Data types**

# %%
name ="Sunil"
print(type(name))
# Out:
# <class 'str'>

# %%
name2="Sunil Dyamakkanavar & 123"
print(type(name2))
# Out:
# <class 'str'>

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# sequence data type
# lists
# tuple
# range
#
# 1.ordered
# 2.mutable
# allow duplicates

# %%
lis=['sunil','123','17.10']
type(lis)
# Out:
# list

# %% [markdown]
# Tuples-->storing multiple items in a single variable
# 1.order
# 2.unchangeable
# 3.allow duplicates

# %%
print(lis)
# Out:
# ['sunil', '123', '17.10']

# %%
lis2=['apple','200','india','apple']
print(len(lis))
print(len(lis2))
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# 3
# 4
# ['sunil', '123', '17.10', 'apple', '200', 'india', 'apple']
# 7

# %%
lis2.append('Hubli')

# %%
lis2
# Out:
# ['apple', '200', 'india', 'apple', 'Hubli']

# %%
lis[2]
# Out:
# '17.10'

# %%
a=9
b=6
c=10
sum=(a+b)*c
print(sum)
# Out:
# 150

# %%
lis.sort()

# %%
lis
# Out:
# ['123', '17.10', 'sunil']

# %%
lis2
# Out:
# ['apple', '200', 'india', 'apple', 'Hubli']

# %%
lis2.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
lis2
# Out:
# ['apple', '200', 'india', 'apple', 'Hubli']

# %%
tuple1=("Hubli","Belgum","Hubli")
print(type(tuple1))
tuple2=("Hubli",)
print(type(tuple2))
tuple3=(1,2,3,4,5)
print(type(tuple3))
tuple4=("asdf","123",1,1,2,3,4,5,True)
print(type(tuple4))
tuple5=tuple((1,2,3,4,5))
print(type(tuple5))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
